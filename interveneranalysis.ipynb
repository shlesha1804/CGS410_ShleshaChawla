# %%
# !pip install pandas matplotlib seaborn
# !python treebanks.py
# Out:
# ...
# === Downloading UD Treebanks ===
#
# ...
#     → 13.8 MB
# ...
#     → 41.2 MB
# ...
#     → 40.7 MB
# ...
#     → 3.1 MB
# ...
#     → 39.3 MB
# ...
#     → 9.2 MB
# ...
#     → 23.0 MB
# ...
#     → 23.3 MB
# ...
#     → 19.6 MB
#
# Done. Run:  python main.py

# %%
# !python main.py
# Out:
# [Processing] English ← treebanks/en_ewt-ud-train.conllu
#   Loaded 12544 sentences
#   Found 124099 non-adjacent dependency pairs with interveners
#
# [Processing] Hindi ← treebanks/hi_hdtb-ud-train.conllu
#   Loaded 13306 sentences
#   Found 362448 non-adjacent dependency pairs with interveners
#
# [Processing] Arabic ← treebanks/ar_padt-ud-train.conllu
#   Loaded 6075 sentences
#   Found 168014 non-adjacent dependency pairs with interveners
#
# [Processing] Turkish ← treebanks/tr_imst-ud-train.conllu
#   Loaded 3435 sentences
#   Found 25956 non-adjacent dependency pairs with interveners
#
# [Processing] Japanese ← treebanks/ja_gsd-ud-train.conllu
#   Loaded 7050 sentences
#   Found 146750 non-adjacent dependency pairs with interveners
#
# [Processing] Chinese ← treebanks/zh_gsd-ud-train.conllu
#   Loaded 3997 sentences
#   Found 86988 non-adjacent dependency pairs with interveners
#
# [Processing] French ← treebanks/fr_gsd-ud-train.conllu
#   Loaded 14450 sentences
# ...

# %%
from IPython.display import Image, display

display(Image("output/heatmap_arity.png"))
display(Image("output/heatmap_subtree.png"))
display(Image("output/bar_heads_structure.png"))
display(Image("output/stacked_pos.png"))
display(Image("output/violin_dep_length.png"))

# %%
import pandas as pd
df = pd.read_csv("output/intervener_stats.csv")
df
# Out:
#    language  deprel  n_pairs  mean_dep_length  median_dep_length  mean_arity  \
# 0    Arabic  advmod     4460           15.604                9.0       0.646
# 1    Arabic    amod     7206            4.035                3.0       0.261
# 2    Arabic     det     1210           13.392                9.0       0.575
# 3    Arabic    nmod    45027            6.377                4.0       0.315
# 4    Arabic   nsubj    18580           10.596                7.0       0.546
# ..      ...     ...      ...              ...                ...         ...
# 58  Turkish     det      275            5.404                3.0       0.360
# 59  Turkish    nmod     3796            7.599                5.0       0.465
# 60  Turkish   nsubj     9528           10.422                9.0       0.601
# 61  Turkish     obj     2164            6.974                5.0       0.505
# 62  Turkish     obl     5516            8.874                7.0       0.553
#
# ...

# %%
import pandas as pd
df = pd.read_csv("output/raw_records.csv")
df
# Out:
#         language  sent_id  deprel  head_id  dep_id  dep_length  intervener_id  \
# 0        English        0    nmod       15      18           3             16
# 1        English        0    nmod       15      18           3             17
# 2        English        0    nmod       18      21           3             19
# 3        English        0    nmod       18      21           3             20
# 4        English        0    nmod       21      23           2             22
# ...          ...      ...     ...      ...     ...         ...            ...
# 1673846   German    13813     obj       27      23           4             25
# 1673847   German    13813     obj       27      23           4             26
# 1673848   German    13813  advmod       27      24           3             25
# 1673849   German    13813  advmod       27      24           3             26
# 1673850   German    13813   nsubj       27      25           2             26
#
# ...
